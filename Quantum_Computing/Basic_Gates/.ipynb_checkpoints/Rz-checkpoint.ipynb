# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
q = QuantumRegister(1)
c = ClassicalRegister(1)
qc = QuantumCircuit(q,c)

# %%
qc.draw('mpl')

# %%
from qiskit.quantum_info import Statevector

# %%
psi1 = Statevector(qc)
psi1.draw('latex')
# Out:
# $$ |0\rangle$$

# %%
from qiskit.visualization import plot_state_qsphere

# %%
plot_state_qsphere(qc)

# %%
from qiskit.visualization import plot_bloch_multivector
plot_bloch_multivector(qc)

# %%
from math import pi

# %%
qc.rz(pi,q[0])

# %%
qc.draw('mpl')

# %%
psi2 = Statevector(qc)
psi2.draw('latex')
# Out:
# $$- i |0\rangle$$

# %%
plot_state_qsphere(qc)

# %%
from qiskit.quantum_info import DensityMatrix

# %%
rho2 = DensityMatrix(qc)
rho2.draw('latex',prefix='\\rho_2=')
# Out:
# $$
# \rho_2=
# \begin{bmatrix}
# 1 & 0  \\
#  0 & 0  \\
#  \end{bmatrix}
# $$

# %%
purityf = rho2.purity()
print(purityf)
# Out:
# (1+0j)

# %%
qc.measure(q[0],c[0])

# %%
qc.draw('mpl')

# %%
from qiskit import transpile
from qiskit_aer import QasmSimulator
backend = QasmSimulator()
qc_compiled = transpile(qc,backend)
job = backend.run(qc_compiled,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
# Out:
# {'0': 1024}

# %%
from qiskit.visualization import plot_histogram
plot_histogram(counts)

# %%
qc2 = QuantumCircuit(q,c)

# %%
qc2.x(q[0])

# %%
qc2.draw('mpl')

# %%
psi1 = Statevector(qc2)
psi1.draw('latex')
# Out:
# $$ |1\rangle$$

# %%
rho1 = DensityMatrix(qc2)
rho1.draw('latex',prefix='\\rho_1 =')
# Out:
# $$
# \rho_1 =
# \begin{bmatrix}
# 0 & 0  \\
#  0 & 1  \\
#  \end{bmatrix}
# $$

# %%
from math import pi

# %%
qc2.rz(pi/6,q[0])

# %%
qc2.draw('mpl')

# %%
psi2 = Statevector(qc2)
psi2.draw('latex')
# Out:
# $$(0.9659258263 + 0.2588190451 i) |1\rangle$$

# %%
rho2 = DensityMatrix(qc2)
rho2.draw('latex',prefix='\\rho_2=')
# Out:
# $$
# \rho_2=
# \begin{bmatrix}
# 0 & 0  \\
#  0 & 1  \\
#  \end{bmatrix}
# $$

# %%
plot_state_qsphere(qc2)

# %%
plot_bloch_multivector(qc2)

# %%
purity = rho2.purity()
print(purity)
# Out:
# (1+0j)

# %%
qc2.measure(q[0],c[0])

# %%
qc2.draw('mpl')

# %%
from qiskit import transpile
from qiskit_aer import QasmSimulator
backend = QasmSimulator()
qc_compiled = transpile(qc,backend)
job = backend.run(qc_compiled,shots = 1024)
result = job.result()
counts = result.get_counts()
print(counts)
# Out:
# {'0': 1024}

# %%
from qiskit.visualization import plot_histogram
plot_histogram(counts)
