# %%
s = '1111'

# %%
n = len(s)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
q = QuantumRegister(2*n)
c = ClassicalRegister(2*n)
qc = QuantumCircuit(q,c)

# %%
qc.draw('mpl')

# %%
for i in range(n):
    qc.h(q[i])
qc.barrier()
qc.draw('mpl')

# %%
def simon_oracle(secret_string):
    """
    Constructs a Simon Oracle quantum circuit for a given secret string.
    

    """
    n = len(secret_string)  # Number of input/output qubits
    oracle = QuantumCircuit(2 * n)  # Create a circuit with n input qubits and n output qubits
    
    for i, bit in enumerate(secret_string):
        if bit == '1':
            oracle.cx(i, i + n)
            oracle.cx(0, i + n)  

    return oracle

# %%
simon = simon_oracle(s)
simon.draw('mpl')
# Draw the Simon oracle circuit

# %%
qc= qc.compose(simon)

# %%
qc.draw('mpl')

# %%
qc.barrier()
# Out:
# CircuitInstruction(operation=Instruction(name='barrier', num_qubits=8, num_clbits=0, params=[]), qubits=(Qubit(QuantumRegister(8, 'q1'), 0), Qubit(QuantumRegister(8, 'q1'), 1), Qubit(QuantumRegister(8, 'q1'), 2), Qubit(QuantumRegister(8, 'q1'), 3), Qubit(QuantumRegister(8, 'q1'), 4), Qubit(QuantumRegister(8, 'q1'), 5), Qubit(QuantumRegister(8, 'q1'), 6), Qubit(QuantumRegister(8, 'q1'), 7)), clbits=())

# %%
for i in range(n):
    qc.h(q[i])
qc.barrier()
qc.draw('mpl')

# %%
for i in range(n):
    qc.measure(q[i],c[i])
qc.draw('mpl')
